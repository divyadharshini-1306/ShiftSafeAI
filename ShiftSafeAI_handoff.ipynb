# %% [markdown]
# <a href="https://colab.research.google.com/github/divyadharshini-1306/ShiftSafeAI/blob/main/ShiftSafeAI_handoff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import json

# Write the handoff README
readme = """
# ShiftSafe AI — Model Handoff
# ==========================================

## Files to load in FastAPI

1. xgboost_aqi_model.pkl  — XGBoost model (primary)
2. bigru_final.pt         — Bi-GRU model weights
3. scaler.pkl             — StandardScaler (must apply before Bi-GRU input)
4. feature_cols.json      — Exact 17 feature names in correct order
5. ensemble_weights.json  — {xgb_weight: 0.9, gru_weight: 0.1}

## How to call the model

from predict import predict_aqi_ensemble

feature_dict = {
    'PM2.5': 45.2, 'PM10': 78.1, 'NO': 3.1, 'NO2': 18.4,
    'NH3': 12.1, 'CO': 0.8, 'SO2': 5.2, 'O3': 22.1,
    'hour': 14, 'month': 6, 'day_of_week': 2,
    'is_weekend': 0, 'is_shift_hour': 1,
    'AQI_lag1': 89.0, 'AQI_lag3': 85.0,
    'PM25_rolling6': 43.1, 'AQI_rolling6': 87.5
}

predicted_aqi = predict_aqi_ensemble(feature_dict)
# Returns a single float — next hour predicted AQI

## Model performance
# XGBoost alone:  R² 0.9445 | MAE 3.55
# Bi-GRU alone:   R² 0.9046 | MAE 4.80
# Ensemble final: R² 0.9454 | MAE 3.53
"""

readme_path = '/content/drive/MyDrive/ShiftSafe_AI/models/README.txt'
with open(readme_path, 'w') as f:
    f.write(readme)

print("README saved.")

# Verify all 6 required files exist
import os
models_dir = '/content/drive/MyDrive/ShiftSafe_AI/models/'
required = [
    'xgboost_aqi_model.pkl',
    'bigru_final.pt',
    'scaler.pkl',
    'feature_cols.json',
    'ensemble_weights.json',
    'README_for_Aadish.txt'
]

print("\nHandoff package verification:")
all_present = True
for f in required:
    exists = f in os.listdir(models_dir)
    status = "PRESENT" if exists else " MISSING"
    print(f"  {status}  {f}")
    if not exists:
        all_present = False

if all_present:
    print("\n Handoff package complete.")
    print("Share the models/ folder path :")
    print(f"  {models_dir}")
else:
    print("\n Some files missing — check above.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# README saved.
#
# Handoff package verification:
#   PRESENT  xgboost_aqi_model.pkl
#   PRESENT  bigru_final.pt
#   PRESENT  scaler.pkl
#   PRESENT  feature_cols.json
#   PRESENT  ensemble_weights.json
#   PRESENT  README_for_Aadish.txt
#
#  Handoff package complete.
# Share the models/ folder path :
#   /content/drive/MyDrive/ShiftSafe_AI/models/
